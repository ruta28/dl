# %% [markdown]
# # Deep Learning
# ## Lab Assignment 8 - MNIST Fashion Dataset Classifier using CNN
# Name: Ruta Lole
#
# Roll no.: 61
#
# PRN: 12310305
#
# Class: TY CSAI-A
#
# Batch: 3

# %% [markdown]
# ## Title:
# Use MNIST Fashion Dataset and create a classifier to classify fashion clothing into categories using CNN.

# %% [markdown]
# ## Setup

# %%
import sys

# !{sys.executable} -m pip install pandas numpy matplotlib scikit-learn kagglehub tensorflow seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (3.0.3)
# Requirement already satisfied: numpy in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (2.4.6)
# Requirement already satisfied: matplotlib in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (3.10.9)
# Requirement already satisfied: scikit-learn in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (1.8.0)
# Requirement already satisfied: kagglehub in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (1.0.1)
# Requirement already satisfied: tensorflow in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (2.21.0)
# Requirement already satisfied: seaborn in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rutal\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\rutal\appdata\roaming\python\python311\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.22 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from kagglehub) (0.1.23)
# Requirement already satisfied: pyyaml in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from kagglehub) (2.34.2)
# Requirement already satisfied: tqdm in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from kagglehub) (4.67.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (7.35.0)
# Requirement already satisfied: setuptools in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\rutal\appdata\roaming\python\python311\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\rutal\appdata\roaming\python\python311\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.14.1)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from requests->kagglehub) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from requests->kagglehub) (3.15)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from requests->kagglehub) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from requests->kagglehub) (2026.5.20)
# Requirement already satisfied: colorama in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rutal\appdata\roaming\python\python311\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rutal\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# [notice] A new release of pip available: 22.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load and Preprocess the Dataset

# %%
# Load the Fashion MNIST dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Normalize pixel values to be between 0 and 1
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Reshape images to add a channel dimension (for CNN input)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 4us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# x_train shape: (60000, 28, 28, 1)
# y_train shape: (60000,)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ## Visualize Sample Data
# Let's display some sample images from the dataset to understand the data.

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %% [markdown]
# ## Build the CNN Model

# %%
model = keras.Sequential([
    keras.Input(shape=(28, 28, 1)), # Input layer
    layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Flatten(),
    layers.Dropout(0.5), # Dropout for regularization
    layers.Dense(10, activation="softmax"), # Output layer with 10 classes for Fashion MNIST
])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        16,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,826 (136.04 KB)
#  Trainable params: 34,826 (136.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Compile the Model

# %%
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# ## Train the Model

# %%
batch_size = 128
epochs = 10

history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.7505 - loss: 0.6885 - val_accuracy: 0.8373 - val_loss: 0.4397
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.8390 - loss: 0.4482 - val_accuracy: 0.8670 - val_loss: 0.3794
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.8557 - loss: 0.4019 - val_accuracy: 0.8717 - val_loss: 0.3593
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.8651 - loss: 0.3745 - val_accuracy: 0.8795 - val_loss: 0.3359
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.8730 - loss: 0.3554 - val_accuracy: 0.8848 - val_loss: 0.3190
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.8787 - loss: 0.3394 - val_accuracy: 0.8862 - val_loss: 0.3096
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - accuracy: 0.8835 - loss: 0.3232 - val_accuracy: 0.8925 - val_loss: 0.2980
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.8872 - loss: 0.3142 - val_accuracy: 0.8933 - val_loss: 0.2896
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.8894 - loss: 0.3085 - val_accuracy: 0.8953 - val_loss: 0.2843
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.8914 - loss: 0.3004 - val_accuracy: 0.8975 - val_loss: 0.2823

# %% [markdown]
# ## Evaluate the Model

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.29417097568511963
# Test accuracy: 0.895799994468689

# %% [markdown]
# ## Visualize Training Results

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.tight_layout()
plt.show()
